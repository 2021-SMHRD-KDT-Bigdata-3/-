# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver as wb
from webdriver_manager.chrome import ChromeDriverManager
import time

# %% [markdown]
# # rpg 크롤링

# %%
driver = wb.Chrome(ChromeDriverManager().install())
driver.get("https://store.steampowered.com/category/rpg/#p=0&tab=NewReleases")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\smhrd\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
#soup = bs(driver.page_source,"lxml")

# %%
#title = soup.select('div#tab_content_NewReleases div.tab_item_name')

# %%
#title[0].text.strip()

# %%
#price = soup.select("div#tab_content_NewReleases div.discount_final_price")

# %%
#tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')

# %%
#btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')

# %%
#btn_next.click()

# %%
time.sleep(3)
btn_search = driver.find_element_by_id('language_pulldown')
btn_search.click()
time.sleep(3)
btn_search = driver.find_element_by_css_selector('#language_dropdown > div > a:nth-child(4)')
btn_search.click()
time.sleep(3)

# %%
rpgtitle_list = []
rpgprice_list = []
rpgtag_list = []
rpgimg_list = []

# %%
for i in range(0,20) :
    soup = bs(driver.page_source,"lxml")
    title = soup.select('div#tab_content_NewReleases div.tab_item_name')
    price = soup.select("div#tab_content_NewReleases div.discount_final_price")
    tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')
    
    for j in range(0,15):
        rpgtitle_list.append(title[j].text.strip())
        try : 
            rpgprice_list.append(price[j].text.strip())
        except :
            rpgprice_list.append('0')
        rpgtag_list.append(tag[j].text.strip())
        
        img = soup.select("#NewReleasesRows > a:nth-child("+(str)(j+1)+") > div.tab_item_cap > img")
        for z in img:
            rpgimg_list.append(z['src'])
    
    
    time.sleep(1)
    btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')
    btn_next.click()
    time.sleep(0.5)

# %%
search = '₩ '
rpgprice_list = [word.strip(search) for word in rpgprice_list]

# %%
len(rpgtitle_list)
# Out:
# 300

# %%
len(rpgprice_list)
# Out:
# 300

# %%
len(rpgtag_list)
# Out:
# 300

# %%
len(rpgimg_list)
# Out:
# 300

# %%
rpg
# Out:
#       장르                              게임명      가격  \
# 0    RPG                       Wildermyth  20,800
# 1    RPG                       Dark Deity  20,800
# 2    RPG                   Going Medieval  26,000
# 3    RPG                   The Last Spell  18,450
# 4    RPG                       Griftlands  20,500
# ..   ...                              ...     ...
# 295  RPG              Eviron's Chronicles      무료
# 296  RPG  Arkham Horror: Mother's Embrace  20,500
# 297  RPG                        Sentience      무료
# 298  RPG               Crystal Raiders VR  15,500
# 299  RPG               Legends of Ellaria  26,000
#
#                                     태그  \
# 0    풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1            턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2         앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3        앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4              카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ..                                 ...
# 295        카드 게임, 테이블탑, 대규모 멀티플레이어, 2D
# 296             어드벤처, 롤플레잉, 러브크래프트, 폭력
# 297             앞서 해보기, 소셜 디덕션, 생존, 잠입
# 298         앞서 해보기, 전략 RPG, 1인칭 슈팅, 양궁
# 299                 롤플레잉, 전략, 액션, 어드벤처
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
# 데이터 프레임
import pandas as pd
dic = {"장르":"RPG", "게임명":rpgtitle_list, "가격":rpgprice_list, "태그":rpgtag_list, "이미지":rpgimg_list}
rpg = pd.DataFrame(dic)
rpg
# Out:
#       장르                                 게임명      가격  \
# 0    RPG                          Wildermyth  20,800
# 1    RPG                          Dark Deity  20,800
# 2    RPG                      Going Medieval  26,000
# 3    RPG                      The Last Spell  18,450
# 4    RPG                          Griftlands  20,500
# ..   ...                                 ...     ...
# 295  RPG     Arkham Horror: Mother's Embrace  20,500
# 296  RPG                           Sentience      무료
# 297  RPG                        No Parachute   5,500
# 298  RPG                  Legends of Ellaria  26,000
# 299  RPG  The night of fire stealing 2/盗火之夜2      무료
#
#                                     태그  \
# 0    풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1            턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2         앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3        앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4              카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ..                                 ...
# 295             어드벤처, 롤플레잉, 러브크래프트, 폭력
# 296             앞서 해보기, 소셜 디덕션, 생존, 잠입
# 297              아케이드, 액션, 미스터리 던전, 비행
# 298                 롤플레잉, 전략, 액션, 어드벤처
# 299          롤플레잉, 어드벤처, 일본 롤플레잉, 턴제전략
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
from urllib.request import urlretrieve
number = 1;
for i in range(len(rpgimg_list)):
    urlretrieve(rpgimg_list[i],'C:/Users/smhrd/Desktop/이미지/' + str(number)+'.jpg')
    number += 1
    time.sleep(2)

# %% [markdown]
# # 전략 크롤링

# %%
driver = wb.Chrome(ChromeDriverManager().install())
driver.get("https://store.steampowered.com/category/strategy/#p=0&tab=NewReleases")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\smhrd\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
time.sleep(3)

btn_search = driver.find_element_by_id('language_pulldown')
btn_search.click()
time.sleep(3)

btn_search = driver.find_element_by_css_selector('#language_dropdown > div > a:nth-child(4)')
btn_search.click()
time.sleep(3)

# %%
strtitle_list = []
strprice_list = []
strtag_list = []
strimg_list= []

# %%
for i in range(0,20) :
    soup = bs(driver.page_source,"lxml")
    title = soup.select('div#tab_content_NewReleases div.tab_item_name')
    price = soup.select("div#tab_content_NewReleases div.discount_final_price")
    tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')
    
    for j in range(0,15):
        strtitle_list.append(title[j].text.strip())
        try : 
            strprice_list.append(price[j].text.strip())
        except :
            strprice_list.append('0')
        strtag_list.append(tag[j].text.strip())
        img = soup.select("#NewReleasesRows > a:nth-child("+(str)(j+1)+") > div.tab_item_cap > img")
        for z in img:
            strimg_list.append(z['src'])
    
    
    time.sleep(1)
    btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')
    btn_next.click()
    time.sleep(0.5)

# %%
search = '₩ '
strprice_list = [word.strip(search) for word in strprice_list]

# %%
dic2 = {"장르":"전략", "게임명":strtitle_list, "가격":strprice_list, "태그":strtag_list,"이미지":strimg_list}

# %%
stra = pd.DataFrame(dic2)
stra
# Out:
#      장르                                     게임명      가격  \
# 0    전략                  Spellcaster University  20,800
# 1    전략  Call to Arms - Gates of Hell: Ostfront  20,800
# 2    전략                              Dark Deity  41,000
# 3    전략        Sniper Ghost Warrior Contracts 2  26,000
# 4    전략                          Going Medieval  20,500
# ..   ..                                     ...     ...
# 295  전략                         Empire of Ember  26,000
# 296  전략                          The Wave Story   5,500
# 297  전략                             Blocky Ball      무료
# 298  전략                         Wild Wild Chess   1,650
# 299  전략                    Conquer The Universe      무료
#
#                                태그  \
# 0               전략, 시뮬레이션, 마법, 경영
# 1        실시간 전술, 제2차 세계대전, 전략, 역사
# 2       턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 3             저격수, 1인칭 슈팅, 슈팅, 잠입
# 4    앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# ..                            ...
# 295           앞서 해보기, 액션, 판타지, 전략
# 296     전략, 퍼즐 플랫폼 게임, 퍼즐, 플랫폼 게임
# 297           캐주얼, 스포츠, PvP, 2.5D
# 298        스포츠, 턴제 전술, 턴제전략, 테이블탑
# 299           롤플레잉, 전략, 아이들러, 클리커
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
len(rpgimg_list)
# Out:
# 105

# %%
len(strimg_list)
# Out:
# 300

# %%
number = 301
for i in range(len(strimg_list)):
    urlretrieve(strimg_list[i],'C:/Users/smhrd/Desktop/이미지/' + str(number)+'.jpg')
    number += 1
    time.sleep(2)

# %%
df1 = pd.concat([rpg,stra],ignore_index=True)
df1
# Out:
#       장르                   게임명      가격                                 태그  \
# 0    RPG            Wildermyth  20,800  풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1    RPG            Dark Deity  20,800          턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2    RPG        Going Medieval  26,000       앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3    RPG        The Last Spell  18,450      앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4    RPG            Griftlands  20,500            카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ..   ...                   ...     ...                                ...
# 595   전략       Empire of Ember  26,000                앞서 해보기, 액션, 판타지, 전략
# 596   전략        The Wave Story   5,500          전략, 퍼즐 플랫폼 게임, 퍼즐, 플랫폼 게임
# 597   전략           Blocky Ball      무료                캐주얼, 스포츠, PvP, 2.5D
# 598   전략       Wild Wild Chess   1,650             스포츠, 턴제 전술, 턴제전략, 테이블탑
# 599   전략  Conquer The Universe      무료                롤플레잉, 전략, 아이들러, 클리커
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 595  https://cdn.cloudflare.steamstatic.com/steam/a...
# 596  https://cdn.cloudflare.steamstatic.com/steam/a...
# 597  https://cdn.cloudflare.steamstatic.com/steam/a...
# 598  https://cdn.cloudflare.steamstatic.com/steam/a...
# 599  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [600 rows x 5 columns]

# %% [markdown]
# # 액션

# %%
driver = wb.Chrome(ChromeDriverManager().install())
driver.get("https://store.steampowered.com/category/action/#p=0&tab=NewReleases")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\smhrd\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
time.sleep(3)

btn_search = driver.find_element_by_id('language_pulldown')
btn_search.click()
time.sleep(3)

btn_search = driver.find_element_by_css_selector('#language_dropdown > div > a:nth-child(4)')
btn_search.click()
time.sleep(3)

# %%
acttitle_list = []
actprice_list = []
acttag_list = []
actimg_list= []

# %%
for i in range(0,20) :
    soup = bs(driver.page_source,"lxml")
    title = soup.select('div#tab_content_NewReleases div.tab_item_name')
    price = soup.select("div#tab_content_NewReleases div.discount_final_price")
    tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')
    
    for j in range(0,15):
        acttitle_list.append(title[j].text.strip())
        try : 
            actprice_list.append(price[j].text.strip())
        except :
            actprice_list.append('0')
        acttag_list.append(tag[j].text.strip())
        img = soup.select("#NewReleasesRows > a:nth-child("+(str)(j+1)+") > div.tab_item_cap > img")
        for z in img:
            actimg_list.append(z['src'])
    
    
    time.sleep(1)
    btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')
    btn_next.click()
    time.sleep(0.5)

# %%
search = '₩ '
actprice_list = [word.strip(search) for word in actprice_list]

# %%
dic = {"장르":"액션", "게임명":acttitle_list, "가격":actprice_list, "태그":acttag_list,"이미지":actimg_list}

# %%
act = pd.DataFrame(dic)
act
# Out:
#      장르                                               게임명      가격  \
# 0    액션                                   SAMURAI SHODOWN  64,800
# 1    액션                              GUILTY GEAR -STRIVE-  44,820
# 2    액션  [NINJA GAIDEN: Master Collection] NINJA GAIDEN Σ  16,150
# 3    액션                                     Blade Assault  41,000
# 4    액션                  Sniper Ghost Warrior Contracts 2  17,420
# ..   ..                                               ...     ...
# 295  액션                          God of the Arena Dungeon      무료
# 296  액션                           VERSUS: The Deathscapes   5,500
# 297  액션                                    Pistol Master!      무료
# 298  액션                                    Spacegirl 2038   8,500
# 299  액션                                Thirty Two HardMod   5,500
#
#                                   태그  \
# 0                 액션, 2D 격투, 3D, PvP
# 1             2D 격투, 2.5D, 파이터, 아케이드
# 2                   액션, 폭력, 고어, 어드벤처
# 3         액션, 액션 어드벤처, 플랫폼 게임, 로그라이크
# 4                저격수, 1인칭 슈팅, 슈팅, 잠입
# ..                               ...
# 295  트윈 스틱 슈터, 탑다운 슈터, PvP, 액션 로그라이크
# 296              액션, 어드벤처, 캐주얼, 롤플레잉
# 297               액션, 시뮬레이션, 레이싱, 슈팅
# 298              액션, 2D 격투, 아케이드, 슈팅
# 299            캐주얼, 어드벤처, 액션, 플랫폼 게임
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
number = 601
for i in range(len(actimg_list)):
    urlretrieve(actimg_list[i],'C:/Users/smhrd/Desktop/이미지/' + str(number)+'.jpg')
    number += 1
    time.sleep(2)

# %%
df2 = pd.concat([df1,act],ignore_index=True)
df2
# Out:
#       장르                       게임명      가격                                 태그  \
# 0    RPG                Wildermyth  20,800  풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1    RPG                Dark Deity  20,800          턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2    RPG            Going Medieval  26,000       앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3    RPG            The Last Spell  18,450      앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4    RPG                Griftlands  20,500            카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ..   ...                       ...     ...                                ...
# 895   액션  God of the Arena Dungeon      무료    트윈 스틱 슈터, 탑다운 슈터, PvP, 액션 로그라이크
# 896   액션   VERSUS: The Deathscapes   5,500                액션, 어드벤처, 캐주얼, 롤플레잉
# 897   액션            Pistol Master!      무료                 액션, 시뮬레이션, 레이싱, 슈팅
# 898   액션            Spacegirl 2038   8,500                액션, 2D 격투, 아케이드, 슈팅
# 899   액션        Thirty Two HardMod   5,500              캐주얼, 어드벤처, 액션, 플랫폼 게임
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 895  https://cdn.cloudflare.steamstatic.com/steam/a...
# 896  https://cdn.cloudflare.steamstatic.com/steam/a...
# 897  https://cdn.cloudflare.steamstatic.com/steam/a...
# 898  https://cdn.cloudflare.steamstatic.com/steam/a...
# 899  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [900 rows x 5 columns]

# %% [markdown]
# # 어드벤쳐

# %%
driver = wb.Chrome(ChromeDriverManager().install())
driver.get("https://store.steampowered.com/category/adventure_and_casual/#p=0&tab=NewReleases")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\smhrd\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
time.sleep(2)

btn_search = driver.find_element_by_id('language_pulldown')
btn_search.click()
time.sleep(2)

btn_search = driver.find_element_by_css_selector('#language_dropdown > div > a:nth-child(4)')
btn_search.click()
time.sleep(2)

# %%
advtitle_list = []
advprice_list = []
advtag_list = []
advimg_list= []

# %%
for i in range(0,20) :
    soup = bs(driver.page_source,"lxml")
    title = soup.select('div#tab_content_NewReleases div.tab_item_name')
    price = soup.select("div#tab_content_NewReleases div.discount_final_price")
    tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')
    
    for j in range(0,15):
        advtitle_list.append(title[j].text.strip())
        try : 
            advprice_list.append(price[j].text.strip())
        except :
            advprice_list.append('0')
        advtag_list.append(tag[j].text.strip())
        img = soup.select("#NewReleasesRows > a:nth-child("+(str)(j+1)+") > div.tab_item_cap > img")
        for z in img:
            advimg_list.append(z['src'])
    
    
    time.sleep(1)
    btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')
    btn_next.click()
    time.sleep(0.5)

# %%
search = '₩ '
advprice_list = [word.strip(search) for word in advprice_list]

# %%
len(advimg_list)
# Out:
# 300

# %%
dic5 = {"장르":"어드벤처", "게임명":advtitle_list, "가격":advprice_list, "태그":advtag_list,"이미지":advimg_list}

# %%
adv1 = pd.DataFrame(dic5)
adv1
# Out:
#        장르                                               게임명      가격  \
# 0    어드벤처                              GUILTY GEAR -STRIVE-  64,800
# 1    어드벤처                                        Dark Deity  20,800
# 2    어드벤처  [NINJA GAIDEN: Master Collection] NINJA GAIDEN Σ  44,820
# 3    어드벤처                                        Lumberhill  13,950
# 4    어드벤처                                         Days Gone  58,800
# ..    ...                                               ...     ...
# 295  어드벤처                                       Hyde & Seek      무료
# 296  어드벤처                                        Hellevator   2,200
# 297  어드벤처         Jessie 'Boom' James - a jigsaw chess tale   2,640
# 298  어드벤처                                Husky's Adventures      무료
# 299  어드벤처                                              做个好梦       0
#
#                                  태그  \
# 0            2D 격투, 2.5D, 파이터, 아케이드
# 1         턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2                  액션, 폭력, 고어, 어드벤처
# 3    멀티플레이어, PvP, 협동 캠페인, 로컬 멀티플레이어
# 4      오픈 월드, 포스트아포칼립스, 좀비, 싱글 플레이어
# ..                              ...
# 295      액션, 캐주얼, 플랫폼 게임, 3D 플랫폼 게임
# 296  퍼즐 플랫폼 게임, 2D 플랫폼 개임, 악령, 어드벤처
# 297              캐주얼, 웨스턴, 아메리카, 퍼즐
# 298         캐주얼, 어드벤처, 아케이드, 플랫폼 게임
# 299       롤플레잉, 어드벤처, 퍼즐, 2D 플랫폼 개임
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
number = 901
for i in range(len(advimg_list)):
    urlretrieve(advimg_list[i],'C:/Users/smhrd/Desktop/이미지/' + str(number)+'.jpg')
    number += 1
    time.sleep(1)

# %%
df3 = pd.concat([df2,adv1],ignore_index=True)
df3
# Out:
#         장르                                        게임명      가격  \
# 0      RPG                                 Wildermyth  20,800
# 1      RPG                                 Dark Deity  20,800
# 2      RPG                             Going Medieval  26,000
# 3      RPG                             The Last Spell  18,450
# 4      RPG                                 Griftlands  20,500
# ...    ...                                        ...     ...
# 1195  어드벤처                                Hyde & Seek      무료
# 1196  어드벤처                                 Hellevator   2,200
# 1197  어드벤처  Jessie 'Boom' James - a jigsaw chess tale   2,640
# 1198  어드벤처                         Husky's Adventures      무료
# 1199  어드벤처                                       做个好梦       0
#
#                                      태그  \
# 0     풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1             턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2          앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3         앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4               카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ...                                 ...
# 1195         액션, 캐주얼, 플랫폼 게임, 3D 플랫폼 게임
# 1196     퍼즐 플랫폼 게임, 2D 플랫폼 개임, 악령, 어드벤처
# 1197                 캐주얼, 웨스턴, 아메리카, 퍼즐
# 1198            캐주얼, 어드벤처, 아케이드, 플랫폼 게임
# 1199          롤플레잉, 어드벤처, 퍼즐, 2D 플랫폼 개임
#
#                                                     이미지
# 0     https://cdn.cloudflare.steamstatic.com/steam/a...
# 1     https://cdn.cloudflare.steamstatic.com/steam/a...
# 2     https://cdn.cloudflare.steamstatic.com/steam/a...
# 3     https://cdn.cloudflare.steamstatic.com/steam/a...
# 4     https://cdn.cloudflare.steamstatic.com/steam/a...
# ...                                                 ...
# 1195  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1196  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1197  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1198  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1199  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [1200 rows x 5 columns]

# %% [markdown]
# # 시뮬

# %%
driver = wb.Chrome(ChromeDriverManager().install())
driver.get("https://store.steampowered.com/category/simulation/#p=0&tab=NewReleases")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\smhrd\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
time.sleep(2)

btn_search = driver.find_element_by_id('language_pulldown')
btn_search.click()
time.sleep(2)

btn_search = driver.find_element_by_css_selector('#language_dropdown > div > a:nth-child(4)')
btn_search.click()
time.sleep(2)

# %%
simtitle_list = []
simprice_list = []
simtag_list = []
simimg_list= []

# %%
for i in range(0,20) :
    soup = bs(driver.page_source,"lxml")
    title = soup.select('div#tab_content_NewReleases div.tab_item_name')
    price = soup.select("div#tab_content_NewReleases div.discount_final_price")
    tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')
    
    for j in range(0,15):
        simtitle_list.append(title[j].text.strip())
        try : 
            simprice_list.append(price[j].text.strip())
        except :
            simprice_list.append('0')
        simtag_list.append(tag[j].text.strip())
        img = soup.select("#NewReleasesRows > a:nth-child("+(str)(j+1)+") > div.tab_item_cap > img")
        for z in img:
            simimg_list.append(z['src'])
    
    
    time.sleep(1)
    btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')
    btn_next.click()
    time.sleep(0.5)

# %%
search = '₩ '
simprice_list = [word.strip(search) for word in simprice_list]

# %%
dic15 = {"장르":"시뮬레이션", "게임명":simtitle_list, "가격":simprice_list, "태그":simtag_list,"이미지":simimg_list}

# %%
sim = pd.DataFrame(dic15)
sim
# Out:
#         장르                                        게임명      가격  \
# 0    시뮬레이션                     Spellcaster University  20,800
# 1    시뮬레이션                                    DRIFT21  20,800
# 2    시뮬레이션                        PowerWash Simulator  20,500
# 3    시뮬레이션                                       모태솔로  23,400
# 4    시뮬레이션                             Going Medieval  26,000
# ..     ...                                        ...     ...
# 295  시뮬레이션                               First Feudal  17,420
# 296  시뮬레이션               Ghost of Tomorrow: Chapter 1   3,300
# 297  시뮬레이션  The Journey - Episode 1: Whatever This Is   2,200
# 298  시뮬레이션                                  Machinist      무료
# 299  시뮬레이션                                   SORALAND  15,500
#
#                                태그  \
# 0               전략, 시뮬레이션, 마법, 경영
# 1       시뮬레이션, 레이싱, 자동차 시뮬레이션, 운전
# 2             시뮬레이션, 캐주얼, 인디, 릴랙싱
# 3            시뮬레이션, FMV, 시네마틱, 대화
# 4    앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# ..                            ...
# 295      식민지 시뮬레이션, 기지 건설, 생존, 경영
# 296            고어, 인디, 캐주얼, 시뮬레이션
# 297      선택의 중요, 복수 결말, 릴랙싱, 감정적인
# 298        앞서 해보기, 캐주얼, 인디, 시뮬레이션
# 299            전략, 실시간 전략, 경영, 건설
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
number = 1201
for i in range(len(simimg_list)):
    urlretrieve(simimg_list[i],'C:/Users/smhrd/Desktop/이미지/' + str(number)+'.jpg')
    number += 1
    time.sleep(1)

# %%
#############

# %%
df4 = pd.concat([df3,sim],ignore_index=True)
df4
# Out:
#          장르                                        게임명      가격  \
# 0       RPG                                 Wildermyth  20,800
# 1       RPG                                 Dark Deity  20,800
# 2       RPG                             Going Medieval  26,000
# 3       RPG                             The Last Spell  18,450
# 4       RPG                                 Griftlands  20,500
# ...     ...                                        ...     ...
# 1495  시뮬레이션                               First Feudal  17,420
# 1496  시뮬레이션               Ghost of Tomorrow: Chapter 1   3,300
# 1497  시뮬레이션  The Journey - Episode 1: Whatever This Is   2,200
# 1498  시뮬레이션                                  Machinist      무료
# 1499  시뮬레이션                                   SORALAND  15,500
#
#                                      태그  \
# 0     풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1             턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2          앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3         앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4               카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ...                                 ...
# 1495           식민지 시뮬레이션, 기지 건설, 생존, 경영
# 1496                 고어, 인디, 캐주얼, 시뮬레이션
# 1497           선택의 중요, 복수 결말, 릴랙싱, 감정적인
# 1498             앞서 해보기, 캐주얼, 인디, 시뮬레이션
# 1499                 전략, 실시간 전략, 경영, 건설
#
#                                                     이미지
# 0     https://cdn.cloudflare.steamstatic.com/steam/a...
# 1     https://cdn.cloudflare.steamstatic.com/steam/a...
# 2     https://cdn.cloudflare.steamstatic.com/steam/a...
# 3     https://cdn.cloudflare.steamstatic.com/steam/a...
# 4     https://cdn.cloudflare.steamstatic.com/steam/a...
# ...                                                 ...
# 1495  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1496  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1497  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1498  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1499  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [1500 rows x 5 columns]

# %% [markdown]
# # 스포츠 및 레이싱

# %%
driver = wb.Chrome(ChromeDriverManager().install())
driver.get("https://store.steampowered.com/category/sports_and_racing/#p=0&tab=NewReleases")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\smhrd\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
time.sleep(2)

btn_search = driver.find_element_by_id('language_pulldown')
btn_search.click()
time.sleep(2)

btn_search = driver.find_element_by_css_selector('#language_dropdown > div > a:nth-child(4)')
btn_search.click()
time.sleep(2)

# %%
spttitle_list = []
sptprice_list = []
spttag_list = []
sptimg_list= []

# %%
for i in range(0,20) :
    soup = bs(driver.page_source,"lxml")
    title = soup.select('div#tab_content_NewReleases div.tab_item_name')
    price = soup.select("div#tab_content_NewReleases div.discount_final_price")
    tag = soup.select('div#tab_content_NewReleases div.tab_item_top_tags')
    
    for j in range(0,15):
        spttitle_list.append(title[j].text.strip())
        try : 
            sptprice_list.append(price[j].text.strip())
        except :
            sptprice_list.append('0')
        spttag_list.append(tag[j].text.strip())
        img = soup.select("#NewReleasesRows > a:nth-child("+(str)(j+1)+") > div.tab_item_cap > img")
        for z in img:
            sptimg_list.append(z['src'])
    
    
    time.sleep(1)
    btn_next = driver.find_element_by_xpath('//*[@id="NewReleases_btn_next"]')
    btn_next.click()
    time.sleep(0.5)

# %%
search = '₩ '
sptprice_list = [word.strip(search) for word in sptprice_list]

# %%
dic16 = {"장르":"스포츠 및 레이싱", "게임명":spttitle_list, "가격":sptprice_list, "태그":spttag_list,"이미지":sptimg_list}

# %%
spt = pd.DataFrame(dic16)
spt
# Out:
#             장르                            게임명      가격  \
# 0    스포츠 및 레이싱                      Days Gone  58,800
# 1    스포츠 및 레이싱                 Knockout City™  22,000
# 2    스포츠 및 레이싱                        DRIFT21  20,800
# 3    스포츠 및 레이싱                      BIOMUTANT  64,900
# 4    스포츠 및 레이싱                     SnowRunner  31,800
# ..         ...                            ...     ...
# 295  스포츠 및 레이싱     Vaccine Delivery Simulator   6,500
# 296  스포츠 및 레이싱                    Synth Drift   1,100
# 297  스포츠 및 레이싱        Endless Furry Blackjack   1,100
# 298  스포츠 및 레이싱                     Mage Drops  12,500
# 299  스포츠 및 레이싱  Hyperspace : Andy's Adventure   6,500
#
#                                           태그  \
# 0               오픈 월드, 포스트아포칼립스, 좀비, 싱글 플레이어
# 1                      멀티플레이어, 스포츠, 팀 기반, 경쟁
# 2                  시뮬레이션, 레이싱, 자동차 시뮬레이션, 운전
# 3                   오픈 월드, 액션, 롤플레잉, 싱글 플레이어
# 4               어드벤처, 시뮬레이션, 자동차 시뮬레이션, 샌드박스
# ..                                       ...
# 295                      시뮬레이션, 액션, 물리게임, 유머
# 296                        레이싱, 아케이드, 2D, 운전
# 297                       캐주얼, 스포츠, 전략, 아케이드
# 298  앞서 해보기, 2D 플랫폼 개임, 3D 플랫폼 게임, 퍼즐 플랫폼 게임
# 299                     레이싱, 시간 관리, 비행, 아케이드
#
#                                                    이미지
# 0    https://cdn.cloudflare.steamstatic.com/steam/a...
# 1    https://cdn.cloudflare.steamstatic.com/steam/a...
# 2    https://cdn.cloudflare.steamstatic.com/steam/a...
# 3    https://cdn.cloudflare.steamstatic.com/steam/a...
# 4    https://cdn.cloudflare.steamstatic.com/steam/a...
# ..                                                 ...
# 295  https://cdn.cloudflare.steamstatic.com/steam/a...
# 296  https://cdn.cloudflare.steamstatic.com/steam/a...
# 297  https://cdn.cloudflare.steamstatic.com/steam/a...
# 298  https://cdn.cloudflare.steamstatic.com/steam/a...
# 299  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [300 rows x 5 columns]

# %%
number = 1501
for i in range(len(sptimg_list)):
    urlretrieve(sptimg_list[i],'C:/Users/smhrd/Desktop/이미지/' + str(number)+'.jpg')
    number += 1
    time.sleep(1)

# %%
df5 = pd.concat([df4,spt],ignore_index=True)
df5
# Out:
#              장르                            게임명      가격  \
# 0           RPG                     Wildermyth  20,800
# 1           RPG                     Dark Deity  20,800
# 2           RPG                 Going Medieval  26,000
# 3           RPG                 The Last Spell  18,450
# 4           RPG                     Griftlands  20,500
# ...         ...                            ...     ...
# 1795  스포츠 및 레이싱     Vaccine Delivery Simulator   6,500
# 1796  스포츠 및 레이싱                    Synth Drift   1,100
# 1797  스포츠 및 레이싱        Endless Furry Blackjack   1,100
# 1798  스포츠 및 레이싱                     Mage Drops  12,500
# 1799  스포츠 및 레이싱  Hyperspace : Andy's Adventure   6,500
#
#                                            태그  \
# 0           풍부한 스토리, 파티 기반 RPG, 선택의 중요, 턴제 전술
# 1                   턴제 전술, 턴제전략, 전략 RPG, 어드벤처
# 2                앞서 해보기, 도시 건설, 식민지 시뮬레이션, 중세
# 3               앞서 해보기, 턴제 전투, 리플레이 가치, 기지 건설
# 4                     카드 배틀, 로그라이트, 롤플레잉, 덱빌딩
# ...                                       ...
# 1795                      시뮬레이션, 액션, 물리게임, 유머
# 1796                        레이싱, 아케이드, 2D, 운전
# 1797                       캐주얼, 스포츠, 전략, 아케이드
# 1798  앞서 해보기, 2D 플랫폼 개임, 3D 플랫폼 게임, 퍼즐 플랫폼 게임
# 1799                     레이싱, 시간 관리, 비행, 아케이드
#
#                                                     이미지
# 0     https://cdn.cloudflare.steamstatic.com/steam/a...
# 1     https://cdn.cloudflare.steamstatic.com/steam/a...
# 2     https://cdn.cloudflare.steamstatic.com/steam/a...
# 3     https://cdn.cloudflare.steamstatic.com/steam/a...
# 4     https://cdn.cloudflare.steamstatic.com/steam/a...
# ...                                                 ...
# 1795  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1796  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1797  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1798  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1799  https://cdn.cloudflare.steamstatic.com/steam/a...
#
# [1800 rows x 5 columns]

# %%
df5.to_csv("game_data.csv", encoding = "UTF-8")
